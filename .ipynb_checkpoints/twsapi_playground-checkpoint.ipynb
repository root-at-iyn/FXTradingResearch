# %%
import ibapi

print("TWS API Version:", ibapi.__version__)
# Out:
# TWS API Version: 10.44.1

# %%
import datetime
import time
import threading
from ibapi.client import *
from ibapi.wrapper import *

port = 4002

class TestApp(EClient, EWrapper):
    def __init__(self):
        EClient.__init__(self, self)

    def nextValidId(self, orderId):
        self.orderId = orderId

    def nextId(self):
        self.orderId += 1
        return self.orderId
    
    def error(self, reqid, errorTime, errorCode, errorString, advancedOrderRejectJson=""):
        print(
            f"""Error. Id: {orderId},
            errotTime: {errorTime},
            errorCode: {errorCode}, 
            errorString: {errorString}, 
            orderReject: {advancedOrderRejectJson}"""
            )
    def historicalData(self, reqId, bar):
        print(reqId, bar)

    def historicalDataEnd(self, reqId, start, end):
        print(f"Historical Data Ended for {reqId}. Started at {start}, ending {end}")
        self.cancelHistoricalData(reqId)

app = TestApp()
app.connect("127.0.0.1", port, 0)
threading.Thread(target=app.run).start()
time.sleep(1)
# Contract details
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       2 import time
#       3 import threading
# ----> 4 from ibapi.client import *
#       5 from ibapi.wrapper import *
#       7 port = 4002
#
# File ~/Projects/FinancialTrading/venv/lib/python3.9/site-packages/ibapi/client.py:286
#     281 # TODO: use pylint
#     283 logger = logging.getLogger(__name__)
# --> 286 class EClient(object):
#     287     (DISCONNECTED, CONNECTING, CONNECTED) = range(3)
#     289     def __init__(self, wrapper):
#
# File ~/Projects/FinancialTrading/venv/lib/python3.9/site-packages/ibapi/client.py:2807, in EClient()
#    2804         self.wrapper.error(orderId, currentTimeMillis(), FAIL_SEND_ORDER.code(), FAIL_SEND_ORDER.msg() + str(ex))
#    2805         return
# -> 2807 def validateOrderParameters(self, order) -> str | None:
#    2808     if self.serverVersion() < MIN_SERVER_VER_ADDITIONAL_ORDER_PARAMS_1:
#    2809         if order.HasField('deactivate'):
#
# TypeError: unsupported operand type(s) for |: 'type' and 'NoneType'
